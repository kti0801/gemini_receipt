# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Markdown

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDsumxlSpTO4IM3B96aKxy8myUE3sEbG5U"

# %%
# %pip install -U --quiet langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 6.5 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("네이버에 대해 보고서를 작성해줘")
Markdown(result.content)
# Out:
# **네이버**
#
# **1. 개요**
#
# 네이버는 1999년에 설립된 대한민국의 인터넷 검색 엔진 및 포털 웹사이트이다. 대한민국에서 가장 많이 방문하는 웹사이트이자 가장 큰 검색 엔진이다.
#
# **2. 서비스**
#
# 네이버는 다양한 서비스를 제공한다.
#
# * **검색:** 웹, 이미지, 비디오, 뉴스 등의 검색 기능
# * **뉴스:** 실시간 뉴스와 기사 제공
# * **쇼핑:** 온라인 쇼핑몰
# * **지도:** 지도 및 길찾기 서비스
# * **이메일:** 웹 기반 이메일 서비스
# * **카페:** 온라인 커뮤니티 플랫폼
# * **웹툰:** 웹툰 플랫폼
# * **게임:** 온라인 게임 서비스
# * **금융:** 온라인 은행, 증권, 보험 서비스
#
# **3. 시장 점유율**
#
# StatCounter에 따르면, 네이버는 대한민국 검색 엔진 시장에서 약 70%의 점유율을 보유하고 있다. 이는 2위인 구글의 약 25%보다 상당히 높다.
#
# **4. 수익원**
#
# 네이버의 주요 수익원은 다음과 같다.
#
# * **광고:** 검색 결과, 뉴스 기사, 웹사이트에 표시되는 광고
# * **쇼핑:** 온라인 쇼핑몰 수수료
# * **게임:** 온라인 게임 판매 및 구독
# * **금융 서비스:** 수수료 및 이자
#
# **5. 경쟁**
#
# 네이버의 주요 경쟁사는 다음과 같다.
#
# * **구글:** 글로벌 검색 엔진 및 포털 웹사이트
# * **다음:** 대한민국의 검색 엔진 및 포털 웹사이트
# * **카카오:** 대한민국의 인스턴트 메시징 앱 및 포털 웹사이트
#
# **6. 미래 전망**
#
# 네이버는 인공 지능, 클라우드 컴퓨팅, 전자상거래를 포함한 신기술에 투자하고 있다. 회사는 글로벌 시장으로의 확장을 계획하고 있다.
#
# **7. 결론**
#
# ...

# %%
# %pip install -U --quiet langchain tiktoken pypdf sentence_transformers chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 45.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/drive/MyDrive/portfolio_kimtoil.pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("프로젝트 개요에 대해 알려줘")
# Out:
# [Document(page_content='Project\x01동화책\x01텍스트\x01감성분석에\x01따라\x01맞춤형\x01감정표현\x01제공하는\x013D\x01아바타\x01개발\x01프로젝트\n프로젝트\x01결과\n텍스트\x01감성\x01분류모델\x01(Koelectra-base-v3)\n이미지\x01생성\x01모델(STARGAN)이미지\x01감성\x01분류모델\x01\nGoogleNet\x01+\x01EfficientNet\x01앙상블\x01(Soft\x01voting)\n3D\x01모델(Deca)', metadata={'page': 3, 'source': '/content/drive/MyDrive/portfolio_kimtoil.pdf'}),
#  Document(page_content='2019 2020 2021 2022 2023 2024\nIntroduction\n010-9999-9902\nkimtoil205@gmail.com\nNotion\x01LinkEnvironmentStacks\nToolsPython,\x01JavaopenCV\nPyTorchTensorflow\nPandas\nWindow\x0110(Vscode)\nAnaconda(jupyter)\nGit Notion\nHISTORY\n한국어외국어대학교\n(컴퓨터전자시스템공학부)AI\x01공부\x01시작\nAI\x01관련\x01들은\x01수업\x01:\x01데이터마이닝,\x01기계학습,\x01자연어처리\x01김\x01토\x01일\nKIM\x01TO\x01IL\nAI\x01developer\x01새로운\x01기술(지식)을\x01익히는\x01것을\x01즐깁니다.\x01\x01\n문제\x01해결에\x01보람을\x01느낍니다.', metadata={'page': 0, 'source': '/content/drive/MyDrive/portfolio_kimtoil.pdf'}),
# ...

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0)

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
Markdown(chain.invoke({'question': "내가 했던 프로젝트에 대해 설명해줘"}).content)
# Out:
# 감성 분석에 따라 맞춤형 감정 표현을 제공하는 3D 아바타 개발 프로젝트를 진행했습니다.
